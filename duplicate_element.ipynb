# %% [markdown]
# <a href="https://colab.research.google.com/github/amitsurjo57/ds-ml-assignment/blob/assignment-1-(mod-2)/duplicate_element.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num_list = [1, 5, 6, 5, 1, 2, 3]

num_set = set(num_list)

num_list = list(num_set)

print(num_list)
