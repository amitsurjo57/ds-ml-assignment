# %% [markdown]
# <a href="https://colab.research.google.com/github/amitsurjo57/ds-ml-assignment/blob/assignment-1-(mod-2)/average.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def average(a, b):
  return (a+b)/2


a = int(input("Enter first numbers: "))
b = int(input("Enter second numbers: "))

print(f"The average of {a} and {b} is: {average(a, b)}")
