# %% [markdown]
# <a href="https://colab.research.google.com/github/amitsurjo57/ds-ml-assignment/blob/assignment-(mod-3)/animal_problem.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Animal:
  def speak(self):
    pass


class Dog(Animal):
  def speak(self):
    print("Woof Woof!")


dog = Dog()

dog.speak()
